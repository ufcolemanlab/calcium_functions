# %%
import torch

# %%
print("PyTorch version:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())
# Out:
# PyTorch version: 2.5.1
# MPS available: False
# MPS built: True

# %%
# 🎯 If MPS remains stubbornly unavailable:
# You can still use Cellpose without MPS—it’ll just be slower.
# Temporarily set Cellpose to CPU explicitly:
import cellpose

if torch.backends.mps.is_available() is False:
    model = models.Cellpose(gpu=False, model_type='cyto')
    print("***>>> SWITCHED TO CPU FOR CELLPOSE <<<***")
    print(model)
    
# This ensures your work progresses even without GPU.
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.4
# platform:       	darwin
# python version: 	3.11.13
# torch version:  	2.5.1! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 import cellpose
#       6 if torch.backends.mps.is_available() is False:
# ----> 7     model = models.Cellpose(gpu=False, model_type='cyto')
#       8     print("***>>> SWITCHED TO CPU FOR CELLPOSE <<<***")
#       9     print(model)
#
# NameError: name 'models' is not defined
